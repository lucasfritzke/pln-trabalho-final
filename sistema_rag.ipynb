# %% [markdown]
# Sistema RAG para busca de filmes por resenhas
# Usando embeddings locais e PostgreSQL com pgVector

# %% [markdown]
# ## Imports

# %%
import os
import re
from pathlib import Path
from typing import List, Tuple
import psycopg2
from psycopg2.extras import execute_values
from sentence_transformers import SentenceTransformer
import numpy as np
