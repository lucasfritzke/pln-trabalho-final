# %%
"""
Servidor MCP para Recomendação de Filmes com RAG
Expõe ferramentas para o LLama 3 buscar filmes no PostgreSQL
"""

import asyncio
import logging
from typing import List, Dict, Any
import psycopg2
import numpy as np
from sentence_transformers import SentenceTransformer
from mcp.server import Server
from mcp.types import Tool, TextContent

# Configuração de logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# ============================================
# CONFIGURAÇÕES
# ============================================

DB_CONFIG = {
    'dbname': 'filmes_rag',
    'user': 'postgres',
    'password': 'senha123',  # ← Altere se necessário
    'host': 'localhost',
    'port': '5432'
}

MODELO_EMBEDDING = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'

# ============================================
# GERENCIADOR DE RECURSOS
# ============================================

class RecursosRAG:
    """Gerencia conexão com banco e modelo de embeddings"""

    def __init__(self):
        self.conn = None
        self.cursor = None
        self.modelo = None

    def inicializar(self):
        """Inicializa recursos"""
        logger.info("🔌 Conectando ao PostgreSQL...")
        self.conn = psycopg2.connect(**DB_CONFIG)
        self.cursor = self.conn.cursor()
        logger.info("✓ Conectado ao PostgreSQL")

        logger.info("🤖 Carregando modelo de embeddings...")
        self.modelo = SentenceTransformer(MODELO_EMBEDDING)

        if self.modelo.device.type == 'cuda':
            logger.info("✓ Modelo carregado na GPU")
        else:
            logger.info("✓ Modelo carregado na CPU")

    def buscar_filmes(self, query: str, top_k: int = 3) -> List[Dict[str, Any]]:
        """
        Busca filmes usando busca vetorial semântica

        Args:
            query: Descrição do que o usuário procura
            top_k: Número de resultados

        Returns:
            Lista de dicionários com informações dos filmes
        """
        logger.info(f"🔍 Buscando: '{query}'")

        # Gera embedding da query
        embedding_query = self.modelo.encode([query], convert_to_numpy=True)[0]

        # Busca no banco
        sql = """
        SELECT
            titulo,
            chunk_texto,
            chunk_index,
            1 - (vetor_embedding <=> %s::vector) as similaridade
        FROM filmes
        ORDER BY vetor_embedding <=> %s::vector
        LIMIT %s;
        """

        embedding_list = embedding_query.tolist()
        self.cursor.execute(sql, (embedding_list, embedding_list, top_k * 2))
        resultados_raw = self.cursor.fetchall()

        # Agrupa por filme e pega o melhor trecho de cada
        filmes_dict = {}
        for titulo, chunk, idx, sim in resultados_raw:
            if titulo not in filmes_dict:
                filmes_dict[titulo] = {
                    'titulo': titulo,
                    'sinopse': chunk[:500],  # Limita tamanho
                    'similaridade': sim,
                    'chunk_index': idx
                }

        # Pega os top_k filmes únicos
        filmes_unicos = sorted(
            filmes_dict.values(),
            key=lambda x: x['similaridade'],
            reverse=True
        )[:top_k]

        logger.info(f"✓ Encontrados {len(filmes_unicos)} filmes")

        return filmes_unicos

    def listar_filmes(self) -> List[str]:
        """
        Lista todos os filmes no banco de dados

        Returns:
            Lista de títulos dos filmes
        """
        logger.info("📋 Listando todos os filmes...")

        self.cursor.execute("""
            SELECT DISTINCT titulo
            FROM filmes
            ORDER BY titulo;
        """)

        titulos = [row[0] for row in self.cursor.fetchall()]
        logger.info(f"✓ {len(titulos)} filmes no banco")

        return titulos

    def estatisticas(self) -> Dict[str, Any]:
        """
        Retorna estatísticas do banco de dados

        Returns:
            Dicionário com estatísticas
        """
        logger.info("📊 Obtendo estatísticas...")

        # Total de chunks
        self.cursor.execute("SELECT COUNT(*) FROM filmes;")
        total_chunks = self.cursor.fetchone()[0]

        # Total de filmes
        self.cursor.execute("SELECT COUNT(DISTINCT titulo) FROM filmes;")
        total_filmes = self.cursor.fetchone()[0]

        stats = {
            'total_filmes': total_filmes,
            'total_chunks': total_chunks,
            'media_chunks': round(total_chunks / total_filmes, 1) if total_filmes > 0 else 0
        }

        logger.info(f"✓ Stats: {stats}")
        return stats

    def fechar(self):
        """Fecha conexões"""
        if self.cursor:
            self.cursor.close()
        if self.conn:
            self.conn.close()
        logger.info("✓ Recursos liberados")


# ============================================
# SERVIDOR MCP
# ============================================

# Instância global dos recursos
recursos = RecursosRAG()

# Criar servidor MCP
server = Server("filmes-rag-server")

@server.list_tools()
async def list_tools() -> List[Tool]:
    """
    Lista as ferramentas disponíveis para o LLM
    """
    return [
        Tool(
            name="buscar_filmes",
            description=(
                "Busca filmes no banco de dados usando busca semântica. "
                "Use esta ferramenta quando o usuário pedir recomendações de filmes, "
                "perguntar sobre filmes específicos, ou buscar por gênero/tema. "
                "A busca entende linguagem natural."
            ),
            inputSchema={
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": (
                            "Descrição do que o usuário procura. "
                            "Exemplos: 'filme de ação', 'comédia romântica', "
                            "'algo emocionante', 'filme com espionagem'"
                        )
                    },
                    "top_k": {
                        "type": "integer",
                        "description": "Número de filmes a retornar (padrão: 3)",
                        "default": 3,
                        "minimum": 1,
                        "maximum": 10
                    }
                },
                "required": ["query"]
            }
        ),
        Tool(
            name="listar_todos_filmes",
            description=(
                "Lista todos os filmes disponíveis no banco de dados. "
                "Use quando o usuário perguntar 'quais filmes você tem?', "
                "'me mostre todos os filmes', ou similar."
            ),
            inputSchema={
                "type": "object",
                "properties": {}
            }
        ),
        Tool(
            name="estatisticas_banco",
            description=(
                "Retorna estatísticas sobre o banco de filmes: "
                "quantos filmes estão indexados, total de trechos, etc. "
                "Use quando o usuário perguntar sobre o tamanho do banco."
            ),
            inputSchema={
                "type": "object",
                "properties": {}
            }
        )
    ]


@server.call_tool()
async def call_tool(name: str, arguments: dict) -> List[TextContent]:
    """
    Executa uma ferramenta quando chamada pelo LLM

    Args:
        name: Nome da ferramenta
        arguments: Argumentos da ferramenta

    Returns:
        Resultado da ferramenta em formato TextContent
    """
    logger.info(f"🔧 Ferramenta chamada: {name}")
    logger.info(f"   Argumentos: {arguments}")

    try:
        if name == "buscar_filmes":
            query = arguments.get("query", "")
            top_k = arguments.get("top_k", 3)

            if not query:
                return [TextContent(
                    type="text",
                    text="Erro: query não pode ser vazia"
                )]

            # Busca filmes
            filmes = recursos.buscar_filmes(query, top_k)

            if not filmes:
                return [TextContent(
                    type="text",
                    text="Nenhum filme encontrado para esta busca."
                )]

            # Formata resultado
            resultado = f"Encontrados {len(filmes)} filmes para '{query}':\n\n"

            for i, filme in enumerate(filmes, 1):
                resultado += f"{i}. **{filme['titulo']}**\n"
                resultado += f"   Relevância: {filme['similaridade']:.1%}\n"
                resultado += f"   Sinopse: {filme['sinopse']}\n\n"

            return [TextContent(type="text", text=resultado)]

        elif name == "listar_todos_filmes":
            titulos = recursos.listar_filmes()

            if not titulos:
                return [TextContent(
                    type="text",
                    text="Banco de dados vazio. Nenhum filme indexado."
                )]

            resultado = f"Total de {len(titulos)} filmes no banco:\n\n"
            resultado += "\n".join(f"• {titulo}" for titulo in titulos)

            return [TextContent(type="text", text=resultado)]

        elif name == "estatisticas_banco":
            stats = recursos.estatisticas()

            resultado = "📊 Estatísticas do Banco de Filmes:\n\n"
            resultado += f"• Total de filmes: {stats['total_filmes']}\n"
            resultado += f"• Total de trechos: {stats['total_chunks']}\n"
            resultado += f"• Média de trechos por filme: {stats['media_chunks']}\n"

            return [TextContent(type="text", text=resultado)]

        else:
            return [TextContent(
                type="text",
                text=f"Erro: Ferramenta '{name}' não encontrada"
            )]

    except Exception as e:
        logger.error(f"❌ Erro ao executar ferramenta: {e}")
        return [TextContent(
            type="text",
            text=f"Erro ao executar ferramenta: {str(e)}"
        )]


# ============================================
# MAIN
# ============================================

async def main():
    """Função principal para iniciar o servidor"""
    try:
        logger.info("🚀 Iniciando servidor MCP para recomendação de filmes...")

        # Inicializa recursos
        recursos.inicializar()

        # Inicia servidor
        logger.info("✓ Servidor MCP pronto!")
        logger.info("   Aguardando conexões do cliente...")

        # Mantém o servidor rodando
        from mcp.server.stdio import stdio_server

        async with stdio_server() as (read_stream, write_stream):
            await server.run(
                read_stream,
                write_stream,
                server.create_initialization_options()
            )

    except KeyboardInterrupt:
        logger.info("\n⚠ Interrompido pelo usuário")
    except Exception as e:
        logger.error(f"❌ Erro fatal: {e}")
        raise
    finally:
        recursos.fechar()
        logger.info("👋 Servidor encerrado")


if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras import __internal__
#       4 from tf_keras import activations
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.__internal__ import backend
#       4 from tf_keras.__internal__ import layers
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.src.backend import _initialize_variables as initialize_variables
#       4 from tf_keras.src.backend import track_variable
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\__init__.py:21
#      15 """Implementation of the TF-Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from tf_keras.src import applications
#      22 from tf_keras.src import distribute
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\applications\__init__.py:18
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from tf_keras.src.applications.convnext import ConvNeXtBase
#      19 from tf_keras.src.applications.convnext import ConvNeXtLarge
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\applications\convnext.py:26
#      25 import numpy as np
# ---> 26 import tensorflow.compat.v2 as tf
#      28 from tf_keras.src import backend
#
# ModuleNotFoundError: No module named 'tensorflow.compat'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2316 try:
# -> 2317     module = self._get_module(self._class_to_module[name])
#    2318     value = getattr(module, name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2344 try:
# -> 2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_tf_utils.py:38
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\activations_tf.py:24
#      23 except (ModuleNotFoundError, ImportError):
# ---> 24     import keras
#      26     if parse(keras.__version__).major > 2:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras import activations as activations
#       8 from keras import applications as applications
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\activations\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize as deserialize
#       8 from keras.src.activations import get as get
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import celu
#       4 from keras.src.activations.activations import elu
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\__init__.py:10
#       9 from keras.src.api_export import keras_export
# ---> 10 from keras.src.backend.common.dtypes import result_type
#      11 from keras.src.backend.common.keras_tensor import KerasTensor
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\common\__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\common\dtypes.py:5
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend\common\variables.py:11
#      10 from keras.src.backend.common.stateless_scope import in_stateless_scope
# ---> 11 from keras.src.utils.module_utils import tensorflow as tf
#      12 from keras.src.utils.naming import auto_name
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\__init__.py:1
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\audio_dataset_utils.py:4
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\dataset_utils.py:9
#       7 import numpy as np
# ----> 9 from keras.src import tree
#      10 from keras.src.api_export import keras_export
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\tree\__init__.py:1
# ----> 1 from keras.src.tree.tree_api import assert_same_paths
#       2 from keras.src.tree.tree_api import assert_same_structure
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\tree\tree_api.py:8
#       7 if optree.available:
# ----> 8     from keras.src.tree import optree_impl as tree_impl
#       9 elif dmtree.available:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\tree\optree_impl.py:13
#      12 if backend() == "tensorflow":
# ---> 13     from tensorflow.python.trackable.data_structures import ListWrapper
#      14     from tensorflow.python.trackable.data_structures import _DictWrapper
#
# ModuleNotFoundError: No module named 'tensorflow.python.trackable'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2316 try:
# -> 2317     module = self._get_module(self._class_to_module[name])
#    2318     value = getattr(module, name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2344 try:
# -> 2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\integrations\integration_utils.py:60
#      59 if is_tf_available():
# ---> 60     from .. import TFPreTrainedModel
#      62 if is_torch_available():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2320, in _LazyModule.__getattr__(self, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2320         raise ModuleNotFoundError(
#    2321             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2322         ) from e
#    2324 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'TFPreTrainedModel'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       9 import psycopg2
#      10 import numpy as np
# ---> 11 from sentence_transformers import SentenceTransformer
#      12 from mcp.server import Server
#      13 from mcp.types import Tool, TextContent
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:29
#      27 from sentence_transformers import __version__
#      28 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 29 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      30 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      31 from sentence_transformers.cross_encoder.util import (
#      32     cross_encoder_init_args_decorator,
#      33     cross_encoder_predict_rank_args_decorator,
#      34 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:19
#      16 from transformers.tokenization_utils_base import BatchEncoding
#      18 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
# ---> 19 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
#      20 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      21 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\SentenceTransformer.py:36
#      33 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
#      34 from typing_extensions import deprecated
# ---> 36 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      37 from sentence_transformers.models import Router
#      38 from sentence_transformers.models.Module import Module
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\model_card.py:26
#      24 from tqdm.autonotebook import tqdm
#      25 from transformers import TrainerCallback
# ---> 26 from transformers.integrations import CodeCarbonCallback
#      27 from transformers.modelcard import make_markdown_table
#      28 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2320, in _LazyModule.__getattr__(self, name)
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2320         raise ModuleNotFoundError(
#    2321             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2322         ) from e
#    2324 elif name in self._modules:
#    2325     try:
#
# ModuleNotFoundError: Could not import module 'CodeCarbonCallback'. Are this object's requirements defined correctly?
